# %% [markdown]
# # **Kaun Banega Crorepati**
# ### (lite version)

# %%
############################## Quiz Data ##############################

# 'quiz' is a list of dict() objects, and the individual dict() objects are containing the keys "questions", "options" and "correct".
# Each "question" is a string, and "options" is a list of string objects. which represent the options of each question.
# "correct" key holds the number that represents the correct option number!

quiz = [{
    "question": "\tWhat type of language is Python?",
    "options": ["Compiled", "Interpreted", "Machine", "None of the above"],
    "correct": 2
}, {
    "question":
    '''\tWhat is the first name of the artist named "The Weeknd"?''',
    "options": ["Abel", "Jake", "Kevin", "Cody"],
    "correct": 1
}, {
    "question": "\tWhich country does Lionel Messi play for?",
    "options": ["Spain", "Portugal", "Mexico", "Argentina"],
    "correct": 4
}, {
    "question":
    "\tWho invented the C language?",
    "options":
    ["Guido van Rossum", "Dennis Ritchie", "James Gosling", "Brendan Eich"],
    "correct":
    2
}, {
    "question":
    "\tWhich country won the first edition of the FIFA Men's World Cup?",
    "options": ["France", "Spain", "Uruguay", "Brazil"],
    "correct": 3
}, {
    "question": "\tWhich nation hosted the 2006 FIFA Men's World Cup?",
    "options": ["England", "Brazil", "Mexico", "Germany"],
    "correct": 4
}, {
    "question": "\tHow many characters does the ASCII Character set have?",
    "options": [1024, 256, 128, 64],
    "correct": 3
}, {
    "question":
    "\tWhich option had the correct answer to question #1 of this quiz?",
    "options": [3, 1, 2, 4],
    "correct": 3
}, {
    "question": "\tHow many characters can a Gmail account password contain?",
    "options": [100, 64, 32, 127],
    "correct": 1
}, {
    "question":
    "\tWhat is the age difference in years between Cristiano Ronaldo and Lionel Messi?",
    "options": [2, 3, 4, 0],
    "correct": 1
}]
reward_levels = [
    1000, 2000, 3000, 5000, 10000, 20000, 40000, 80000, 160000, 320000
]
score, money = 0, 0


############################## Quiz Logic ##############################

print("\n\t\t W E L C O M E  T O  K B C !")
print("\n--------------------------------------------")
for question in quiz:
    # question represents the dictionary i.e. each indiv. question
    print(f"\n {question['question']}")

    for i, j in enumerate(question['options']):
        # enumerating the list element of the dictionary i.e. displaying options
        print(f"\n\t[{i+1}]\t{j}", end='')

    ans = int(input("\n\n\t Enter your choice or 0 to quit : "))

    if ans == 0:  # quit option
        print("\n--------------------------------------------")
        break
    elif ans == question['correct']:
        print("\n\t Correct!")
        money = reward_levels[score]
        print(f"\n\t You just won Rs.{reward_levels[score]} !")
        score += 1
        print("\n--------------------------------------------")
    else:
        print("\n\t Incorrect!")
        print("\n--------------------------------------------")
        break

print(f"\n\t\t You got {score} out of {len(quiz)} correct !")
if score != 0:
    print(f"\n\t\t You're taking home Rs.{money} !")
else:
    print("\n\t\t You failed to win any amount. : (")
